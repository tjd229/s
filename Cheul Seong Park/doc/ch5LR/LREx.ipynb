# %%
import logRegres
reload(logRegres)
dataArr,labelMat=logRegres.loadDataSet()
print logRegres.gradAscent(dataArr,labelMat)
# Out:
# [[ 4.12414349]
#  [ 0.48007329]
#  [-0.6168482 ]]

# %%
import matplotlib
# %matplotlib inline

reload(logRegres)
weights=logRegres.gradAscent(dataArr,labelMat)
logRegres.plotBestFit(weights.getA())
#getA matrix->Array

# %%
reload(logRegres)
from numpy import *
dataArr,labelMat=logRegres.loadDataSet()
weights=logRegres.stocGradAscent0(array(dataArr),labelMat)
logRegres.plotBestFit(weights)

# %%
reload(logRegres)
from numpy import *
dataArr,labelMat=logRegres.loadDataSet()
weights=logRegres.stocGradAscent1(array(dataArr),labelMat)
logRegres.plotBestFit(weights)

# %% [markdown]
# # Case 1
# * fatality based on horse colic

# %%
reload(logRegres)
logRegres.multiTest()
# Out:
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# the error rate of this test is: 0.328358
# after 10 iterations the average error rate is: 0.328358

# %% [markdown]
# # Case 2
# * classify example1
# * soruce : Andrew Ng's Machine Learning Class

# %%
reload(logRegres)
dataArr,labelMat=logRegres.loadDataFromTxt("logistic_data1.txt")
weights=logRegres.stocGradAscent1(array(dataArr),labelMat)
logRegres.logRegresTest(weights,"logistic_test_data1.txt")
# Out:
# the error rate of this test is: 0.400000
# 0.4

# %% [markdown]
# # Case 3
# * classify example2
# * soruce : Andrew Ng's Machine Learning Class

# %%
reload(logRegres)
dataArr,labelMat=logRegres.loadDataFromTxt("logistic_data3.txt")
weights=logRegres.stocGradAscent1(array(dataArr),labelMat)
logRegres.logRegresTest(weights,"logistic_test_data3.txt")
# Out:
# the error rate of this test is: 0.300000
# 0.3
