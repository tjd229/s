# %%
mywd='C:\Users\pcs\s\ch3DT'
# %cd {mywd}
# Out:
# C:\Users\pcs\s\ch3DT

# %%
import trees
reload(trees)
myDat,labels=trees.createDataSet()
print myDat
print trees.calcShannonEnt(myDat)

myDat[0][-1]='maybe'
print myDat
print trees.calcShannonEnt(myDat)
# Out:
# [[1, 1, 'yes'], [1, 1, 'yes'], [1, 0, 'no'], [0, 1, 'no'], [0, 1, 'no']]
# 0.970950594455
# [[1, 1, 'maybe'], [1, 1, 'yes'], [1, 0, 'no'], [0, 1, 'no'], [0, 1, 'no']]
# 1.37095059445

# %%
reload(trees)

myDat,labels=trees.createDataSet()

print myDat

print trees.splitDataSet(myDat,0,1)
print trees.splitDataSet(myDat,0,0)
# Out:
# [[1, 1, 'yes'], [1, 1, 'yes'], [1, 0, 'no'], [0, 1, 'no'], [0, 1, 'no']]
# [1, 'yes']
# [1, 'yes']
# [0, 'no']
# [[1, 'yes'], [1, 'yes'], [0, 'no']]

# %%
reload(trees)
myDat,labels=trees.createDataSet()
print trees.chooseBestFeatureToSplit(myDat)
# Out:
# [1, 1, 1, 0, 0]
# set([0, 1])
# [1, 1, 0, 1, 1]
# set([0, 1])
# 0

# %%
reload(trees)
myDat,labels=trees.createDataSet()
myTree=trees.createTree(myDat,labels)
print myTree
# Out:
# ['flippers']
# ['flippers']
# []
# []
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}}}

# %%
import treePlotter
reload(treePlotter)
import matplotlib
# %matplotlib inline
treePlotter.createPlot()

# %%
reload(treePlotter)
print treePlotter.retrieveTree(1)
myTree=treePlotter.retrieveTree(0)
print myTree
print treePlotter.getNumLeafs(myTree)
print treePlotter.getTreeDepth(myTree)
# Out:
# {'no surfacing': {0: 'no', 1: {'flippers': {0: {'head': {0: 'no', 1: 'yes'}}, 1: 'no'}}}}
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}}}
# 3
# 2

# %%
reload(treePlotter)
myTree=treePlotter.retrieveTree(0)
treePlotter.createPlot(myTree)

myTree['no surfacing'][3]='maybe'
print myTree
treePlotter.createPlot(myTree)
# Out:
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}, 3: 'maybe'}}

# %%
reload(trees)
myDat,labels=trees.createDataSet()
print labels
myTree=treePlotter.retrieveTree(0)
print myTree
print trees.classify(myTree,labels,[1,0])
print trees.classify(myTree,labels,[1,1])
# Out:
# ['no surfacing', 'flippers']
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}}}
# no
# yes

# %%
trees.storeTree(myTree,'classifierStorage.txt')
trees.grabTree('classifierStorage.txt')
# Out:
# {'no surfacing': {0: 'no', 1: {'flippers': {0: 'no', 1: 'yes'}}}}

# %% [markdown]
# # Case 1
# * determine lense type

# %%
fr=open('lenses.txt')
lenses=[inst.strip().split('\t') for inst in fr.readlines()]
lensesLabels=['age','prescript','astigmatic','tearRate']
lensesTree=trees.createTree(lenses,lensesLabels)
print lensesTree
treePlotter.createPlot(lensesTree)
# Out:
# {'taerRate': {'reduced': 'no lenses', 'normal': {'astigmatic': {'yes': {'prescript': {'hyper': {'age': {'pre': 'no lenses', 'presbyopic': 'no lenses', 'young': 'hard'}}, 'myope': 'hard'}}, 'no': {'age': {'pre': 'soft', 'presbyopic': {'prescript': {'hyper': 'soft', 'myope': 'no lenses'}}, 'young': 'soft'}}}}}}

# %% [markdown]
# # Case 2
# * determine spam or not
# * Big DC = Big Discount
# * no word free = presence of word 'free
# * less len 10 = content length is less than 10
# * upper domain kr = xxx.xx.kr
# * source : 만들면서 배우는 기계학습 - 오다카 토모히로 지음

# %%
import matplotlib
# %matplotlib inline
fr=open('spam.txt')
spamSet=[inst.strip().split('\t') for inst in fr.readlines()]
spamLabels=['Big DC','no word free','less len 10','upper domain kr']
spamTree=trees.createTree(spamSet,spamLabels)
print spamTree
treePlotter.createPlot(spamTree)
# Out:
# {'less len 10': {'yes': {'upper domain kr': {'yes': 'no', 'no': {'Big DC': {'yes': 'yes', 'no': {'no word free': {'yes': 'yes', 'no': 'no'}}}}}}, 'no': 'no'}}

# %% [markdown]
# # Case 3
# * determine playing tennis
# * source : https://www.youtube.com/watch?v=eKD5gxPPeY0

# %%
fr=open('tennis.txt')
tennisSet=[inst.strip().split('\t') for inst in fr.readlines()]
tennisLabels=['Outlook','Humidity','Wind']
tennisTree=trees.createTree(tennisSet,tennisLabels)
print tennisTree
treePlotter.createPlot(tennisTree)
# Out:
# {'Outlook': {'Overcast': 'Yes', 'Sunny': {'Humidity': {'High': 'No', 'Normal': 'Yes'}}, 'Rain': {'Wind': {'Strong': 'No', 'Weak': 'Yes'}}}}
